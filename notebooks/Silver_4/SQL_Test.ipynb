# %%
# %sql 
--Select count(*) from F1.silver.circuits;
Select * from F1.silver.circuits Where circuit_id=1 Order By ingestion_date desc;
--Select distinct file_date from F1.bronze.circuits;
--SELECT * FROM F1.silver.etl_batch_status;

# %%
# %sql 
update F1.bronze.circuits set country='Change_3', file_date ='2026-04-28' Where file_date ='2026-04-27';
Select * from F1.bronze.circuits Where file_date ='2026-04-28';
