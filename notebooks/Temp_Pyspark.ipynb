# %%
# %sql
SELECT * from  F1.SILVER.circuits where circuit_id=1 order by created_at desc;

# %%
# %sql
update F1.BRONZE.circuits set file_date='2026-04-25', country='Change_1' where circuit_id=1 and altitude=100;
SELECT * from  F1.BRONZE.circuits where circuit_id=1;
