-- %%
USE catalog F1;
SELECT count(*) FROM BRONZE.circuits;
SELECT count(*) FROM BRONZE.races;
SELECT count(*) FROM BRONZE.constructors;
SELECT count(*) FROM BRONZE.results;
SELECT count(*) FROM BRONZE.pit_stops;
SELECT count(*) FROM BRONZE.lap_times;
SELECT count(*) FROM BRONZE.qualifying;

DESCRIBE EXTENDED  F1.BRONZE.circuits;

SELECT count(*) FROM F1.BRONZE.circuits;
SELECT count(*) FROM F1.BRONZE.races;
SELECT count(*) FROM F1.BRONZE.constructors;
SELECT count(*) FROM F1.BRONZE.drivers;
SELECT count(*) FROM F1.BRONZE.results;
SELECT count(*) FROM F1.BRONZE.pit_stops;
SELECT count(*) FROM F1.BRONZE.lap_times;
SELECT count(*) FROM F1.BRONZE.qualifying;
